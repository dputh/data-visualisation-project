# %%
import pandas as pd
import seaborn as sns
import datetime as dt

file = open("./data/watch-history.json")
data = pd.read_json(file)
data
# Out:
#         header                                              title  \
# 0      YouTube  Watched Companies Just Lost Billions From Twit...
# 1      YouTube                  Watched Huge L for Cryptocurrency
# 2      YouTube          Watched tagesthemen 22:45 Uhr, 13.11.2022
# 3      YouTube  Watched Destiny: Politics, Free Speech, Contro...
# 4      YouTube  Watched I Thought SALT Was Boring. Boy, Was I ...
# ...        ...                                                ...
# 49195  YouTube  Watched https://www.youtube.com/watch?v=03smql...
# 49196  YouTube   Watched Klimaempfang 2019 Professor Harald Lesch
# 49197  YouTube  Watched Energieprofessor Volker Quaschning (Te...
# 49198  YouTube           Watched tagesschau 20:00 Uhr, 26.09.2019
# 49199  YouTube  Watched Trump Now ADMITS to Ukraine Biden Exto...
#
#                                           titleUrl  \
# 0      https://www.youtube.com/watch?v=FHk029I-2pE
# 1      https://www.youtube.com/watch?v=C2ZHs55TMZc
# 2      https://www.youtube.com/watch?v=8WfzylA8gyA
# 3      https://www.youtube.com/watch?v=bqeuFiAUU4o
# 4      https://www.youtube.com/watch?v=PJhGkK93OiI
# ...                                            ...
# 49195  https://www.youtube.com/watch?v=03smqlKbGP0
# 49196  https://www.youtube.com/watch?v=F4jDk2MPZbA
# 49197  https://www.youtube.com/watch?v=z3EoCKgzLo4
# 49198  https://www.youtube.com/watch?v=3_yi33SkFgs
# 49199  https://www.youtube.com/watch?v=g2TLw3fFePs
#
#                                                subtitles  \
# 0      [{'name': 'penguinz0', 'url': 'https://www.you...
# 1      [{'name': 'penguinz0', 'url': 'https://www.you...
# 2      [{'name': 'tagesschau', 'url': 'https://www.yo...
# 3      [{'name': 'Lex Fridman', 'url': 'https://www.y...
# 4      [{'name': 'Alex', 'url': 'https://www.youtube....
# ...                                                  ...
# 49195                                                NaN
# 49196  [{'name': 'HLNUG', 'url': 'https://www.youtube...
# 49197  [{'name': 'Jung & Naiv', 'url': 'https://www.y...
# 49198  [{'name': 'tagesschau', 'url': 'https://www.yo...
# 49199  [{'name': 'David Pakman Show', 'url': 'https:/...
#
#                            time   products         activityControls details  \
# 0      2022-11-14T07:12:44.710Z  [YouTube]  [YouTube watch history]     NaN
# 1      2022-11-14T06:14:34.416Z  [YouTube]  [YouTube watch history]     NaN
# 2      2022-11-14T00:36:35.341Z  [YouTube]  [YouTube watch history]     NaN
# 3      2022-11-14T00:36:24.727Z  [YouTube]  [YouTube watch history]     NaN
# 4      2022-11-14T00:34:23.358Z  [YouTube]  [YouTube watch history]     NaN
# ...                         ...        ...                      ...     ...
# 49195  2019-09-26T21:29:06.920Z  [YouTube]  [YouTube watch history]     NaN
# 49196  2019-09-26T21:04:46.590Z  [YouTube]  [YouTube watch history]     NaN
# 49197  2019-09-26T21:04:34.358Z  [YouTube]  [YouTube watch history]     NaN
# 49198  2019-09-26T20:55:30.347Z  [YouTube]  [YouTube watch history]     NaN
# 49199  2019-09-26T16:59:20.547Z  [YouTube]  [YouTube watch history]     NaN
#
#       description
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 49195         NaN
# 49196         NaN
# 49197         NaN
# 49198         NaN
# 49199         NaN
#
# [49200 rows x 9 columns]

# %%
data.drop("details", "description")
data
# Out:
# /var/folders/zz/fbfjwrf955nctwygv7hgmbqw0000gn/T/ipykernel_58379/3309019989.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data.drop("details", "description")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     549         try:
# --> 550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
#
# KeyError: 'description'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/zz/fbfjwrf955nctwygv7hgmbqw0000gn/T/ipykernel_58379/3309019989.py in <module>
# ----> 1 data.drop("details", "description")
#       2 data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4252             if index is not None or columns is not None:
#    4253                 raise ValueError("Cannot specify both 'labels' and 'index'/'columns'")
# -> 4254             axis_name = self._get_axis_name(axis)
#    4255             axes = {axis_name: labels}
#    4256         elif index is not None or columns is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_name(cls, axis)
#     555     @classmethod
#     556     def _get_axis_name(cls, axis: Axis) -> str:
# --> 557         axis_number = cls._get_axis_number(axis)
#     558         return cls._AXIS_ORDERS[axis_number]
#     559
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
# --> 552             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     553
#     554     @final
#
# ValueError: No axis named description for object type DataFrame

# %%
data["date_time"] = pd.to_datetime(data["time"])
data["time"] = data["date_time"].map(lambda x: x.time())
data["day"] = data["date_time"].map(lambda x: x.day)
data["month"] = data["date_time"].map(lambda x: x.month)
data["year"] = data["date_time"].map(lambda x: x.year)
data["channel"] = data["subtitles"][0:5].map(lambda x: x[0]["name"])

# %%
t = data.head(1)["time"]
t[0]

from dateutil.parser import parse as dtparse
data["time"]=data["time"].apply(dtparse)
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [120], line 6
#       4 from dateutil.parser import parse as dtparse
#       5 data["time"]=data["time"].apply(dtparse)
# ----> 6 data["time"]=data["time"].month
#       7 data
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5894'>5895</a> if (
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5895'>5896</a>     name not in self._internal_names_set
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5896'>5897</a>     and name not in self._metadata
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5897'>5898</a>     and name not in self._accessors
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5898'>5899</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5899'>5900</a> ):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5900'>5901</a>     return self[name]
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py?line=5901'>5902</a> return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'month'
